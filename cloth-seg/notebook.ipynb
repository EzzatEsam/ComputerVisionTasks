# %%
import json

# %%
fj = json.load(open("/teamspace/studios/this_studio/ComputerVisionTasks/cloth-seg/data/fashionist/instances_attributes_train2020.json" , "r"))

# %%
len(set(ann["category_id"] for ann in fj["annotations"]))
# Out:
# 46

# %%
fj["annotations"][0]
# Out:
# {'image_id': 16305,
#  'category_id': 32,
#  'attribute_ids': [218],
#  'segmentation': [[471,
#    390,
#    461,
#    412,
#    457,
#    430,
#    454,
#    455,
#    454,
#    473,
#    457,
#    483,
#    469,
#    489,
#    477,
#    492,
#    485,
#    498,
#    493,
#    499,
#    499,
#    496,
#    500,
#    490,
#    494,
#    479,
#    487,
#    461,
#    485,
#    445,
#    483,
#    434,
#    487,
#    433,
#    489,
#    426,
#    489,
#    412,
#    484,
#    403,
#    480,
#    395,
#    477,
#    392]],
#  'bbox': [454.0, 390.0, 46.0, 109.0],
#  'area': 3052,
#  'iscrowd': 0,
#  'id': 0}

# %%
len(set([cat["supercategory"] for cat in fj["categories"]]))
# Out:
# 12

# %%
set([cat["supercategory"] for cat in fj["categories"]])
# Out:
# {'arms and hands',
#  'closures',
#  'decorations',
#  'garment parts',
#  'head',
#  'legs and feet',
#  'lowerbody',
#  'neck',
#  'others',
#  'upperbody',
#  'waist',
#  'wholebody'}

# %%
{n : i for i,n in enumerate(set([cat["supercategory"] for cat in fj["categories"]]))}
# Out:
# {'closures': 0,
#  'upperbody': 1,
#  'head': 2,
#  'legs and feet': 3,
#  'garment parts': 4,
#  'arms and hands': 5,
#  'decorations': 6,
#  'neck': 7,
#  'others': 8,
#  'lowerbody': 9,
#  'waist': 10,
#  'wholebody': 11}
